# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-geotec/Demo/blob/main/sine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import linalg
from scipy.linalg import hilbert
from scipy.linalg import norm
from scipy.sparse import identity
import numpy as np

n = 15 # Set the matrix dimension

# Create a Hilbert matrix
H  = hilbert(n)
Id = np.dot(H, linalg.inv(H))


# Compare using the Frobenius norm
norm(Id - identity(n))
# Out:
# np.float64(156.0743279226193)

# %%
# !pip install openml
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.8/93.8 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 39.4 MB/s eta 0:00:00
# ...
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11717 sha256=17c71f529ea927c358ffffafd11affbc3e55e8daf41de20604245dbb7bf8d0b6
#   Stored in directory: /root/.cache/pip/wheels/a9/ac/cf/c2919807a5c623926d217c0a18eb5b457e5c19d242c3b5963a
# Successfully built liac-arff
# ...

# %%
import openml

dataset = openml.datasets.get_dataset(dataset_id='iris')
dataset.get_data()
# Out:
# (     sepallength  sepalwidth  petallength  petalwidth           class
#  0            5.1         3.5          1.4         0.2     Iris-setosa
#  1            4.9         3.0          1.4         0.2     Iris-setosa
#  2            4.7         3.2          1.3         0.2     Iris-setosa
#  3            4.6         3.1          1.5         0.2     Iris-setosa
#  4            5.0         3.6          1.4         0.2     Iris-setosa
#  ..           ...         ...          ...         ...             ...
#  145          6.7         3.0          5.2         2.3  Iris-virginica
#  146          6.3         2.5          5.0         1.9  Iris-virginica
#  147          6.5         3.0          5.2         2.0  Iris-virginica
#  148          6.2         3.4          5.4         2.3  Iris-virginica
#  149          5.9         3.0          5.1         1.8  Iris-virginica
#
#  [150 rows x 5 columns],
#  None,
#  [False, False, False, False, True],
# ...

# %%
dataset.get_data()[0]
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset.get_data()[3]
# Out:
# ['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class']
